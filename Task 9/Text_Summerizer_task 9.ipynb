# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import nltk
import urllib.request
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from string import punctuation
from heapq import nlargest
from collections import defaultdict

# %%
#Downloading the stopwords package
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\user.DESKTOP-
# [nltk_data]     DGMLV2O\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\user.DESKTOP-
# [nltk_data]     DGMLV2O\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Scrapping Data from Lucid blog On Time with Chibuike Osita

url="https://lucid.blog/hngi6/post/qa-with-chibuike-osita-49e"
requested_url = urllib.request.urlopen(url).read().decode('utf8','ignore')

# %%
# read the data from the url

soup= BeautifulSoup(requested_url, 'html.parser')

# %%
# find all text that has p tag
text_p = soup.find_all('p')
print(text_p)
# Out:
# [<p class="mx-1 font-weight-bold d-inline-block">Guest</p>, <p class="pb-2" id="user-bio">
#           Important Information
#         </p>, <p class="mb-0 ml-1">Powered by Lucid</p>, <p class="small"><em>Are you sure you want to Unfollow HNG Internship and miss out interesting post?<br> Click the button below to unfollow</br></em></p>, <p class="small"><em>Do you have or would love to have Lucid installed on your domain?<br> Click the button below to follow me</br></em></p>, <p class="post-date">
# <a class="text-secondary" href=" https://lucid.blog/hngi6/home "> Home </a> /
#             <a class="text-secondary" href="../home"> Blog </a> / <span class="text-muted">Q&amp;A with Chibuike Osita</span></p>, <p>Hey guys, it's nice to be here</p>, <p>So my name is Chibuike Emmanuel Osita, but in the community and generally, I'm more commonly known as Mozart, I'm a software engineer and a proud aluminai of this internship. So I'm really happy to be in this space again.</p>, <p>In order to ensure this is organized, I'll talk about the following before the questions.</p>, <p>- Why I became a developer</p>, <p>- What I learned from the internship</p>, <p>- Becoming a product creator</p>, <p>- Why I created legohackers</p>, <p>- Things to focus on to improve your skills.</p>, <p><strong>Why I became a developer</strong></p>, <p>Let's start from the beginning very briefly, I wanted to be an aeronautics engineer, a since I was little, aside becoming spiderman, it's the only thing I found myself thinking about constantly. Until my dad got I and my brother our first computer, it was a compaq presario cq57, pretty old stuff, but it was the beginning for me, I spent a lot of time tinkering with it, installing games and deleting them.</p>, <p>Eventually, I started trying to edit them, I failed miserably, but I learned a little about what programs were, when got into secondary school I met a guy called Izuchukuw, who game me some ideas about programming, I could remember this well because he open youtube one day and told he hacked the internet to view the videos and I freaking believed him , Since then it's been me and computers and programming just felt right.</p>, <p>Before I got into programming actively was about a year after secondary school and I wanted to learn how the world works and an objective look at myself made me understand that I wanted to do this. as a career, so I worked at computer village for a year, before writing jamb for computer science and I got the admission. but the school (FUTO) didn't teach what I was expecting, so I started actively training myself, right around the first year.</p>, <p>I started with C++, one 1 hour everyday for a year, and then java before getting into web development</p>, <p>I wouldn't recommend this route though, all it did for me was to give me some grounded understanding.</p>, <p>If there was anything I would have done differently,</p>, <p>- I would have focused on learning more about what the languages themselves could be used for</p>, <p>- Focused more on design patterns</p>, <p>- mastering singular technologies</p>, <p>the key is to know exactly what you want from your career as a developer and what it would mean for you. For example, because of my enthusiasm, I learned different languages, some of which I didn't use at all (e.g C++), I did get to learn design patterns later, but I always felt I should have started somewhere around there in order to understand the bigger picture.</p>, <p>Singular technologies are all things related to a singular language and it's frameworks, it's everything that concerns the language you are working on, e.g PHP and Laravel, if you know PHP, master it and master Laravel , so everything concerning it as a language and its framework is in your circle of control and understanding.</p>, <p>at the end though, I'm happy about my path, but if you follow the key points, you'll likely get to your ideas faster.</p>, <p>before I end this sections (<strong>why I became a developer</strong>) though, just have the following in mind.</p>, <p>- Don't just follow buzzwords, at the end, all of these technologies are the same.</p>, <p>- And the simplest solution or language to understand and use is most likely the best for you (Occam's razor)</p>, <p>- Focus on the essentials, (is it understandable, does it work, how soon can I get up and running)</p>, <p>the essentials may be different for you, but always keep them in mind.</p>, <p><strong>What I learnt from the internship</strong></p>, <p>The internship started when I just finished my second year  ...

# %%
for i in range(0,len(text_p)):
    text += text_p[i].text
text = text.lower()
# tokenize the text
tokens =[t for t in text.split()]
print(tokens)
# Out:
# ['guest', 'important', 'information', 'powered', 'by', 'lucidare', 'you', 'sure', 'you', 'want', 'to', 'unfollow', 'hng', 'internship', 'and', 'miss', 'out', 'interesting', 'post?', 'click', 'the', 'button', 'below', 'to', 'unfollowdo', 'you', 'have', 'or', 'would', 'love', 'to', 'have', 'lucid', 'installed', 'on', 'your', 'domain?', 'click', 'the', 'button', 'below', 'to', 'follow', 'me', 'home', '/', 'blog', '/', 'q&a', 'with', 'chibuike', 'ositahey', 'guys,', "it's", 'nice', 'to', 'be', 'hereso', 'my', 'name', 'is', 'chibuike', 'emmanuel', 'osita,', 'but', 'in', 'the', 'community', 'and', 'generally,', "i'm", 'more', 'commonly', 'known', 'as', 'mozart,', "i'm", 'a', 'software', 'engineer', 'and', 'a', 'proud', 'aluminai', 'of', 'this', 'internship.', 'so', "i'm", 'really', 'happy', 'to', 'be', 'in', 'this', 'space', 'again.in', 'order', 'to', 'ensure', 'this', 'is', 'organized,', "i'll", 'talk', 'about', 'the', 'following', 'before', 'the', 'questions.-', 'why', 'i', 'became', 'a', 'developer-', 'what', 'i', 'learned', 'from', 'the', 'internship-', 'becoming', 'a', 'product', 'creator-', 'why', 'i', 'created', 'legohackers-', 'things', 'to', 'focus', 'on', 'to', 'improve', 'your', 'skills.why', 'i', 'became', 'a', "developerlet's", 'start', 'from', 'the', 'beginning', 'very', 'briefly,', 'i', 'wanted', 'to', 'be', 'an', 'aeronautics', 'engineer,', 'a', 'since', 'i', 'was', 'little,', 'aside', 'becoming', 'spiderman,', "it's", 'the', 'only', 'thing', 'i', 'found', 'myself', 'thinking', 'about', 'constantly.', 'until', 'my', 'dad', 'got', 'i', 'and', 'my', 'brother', 'our', 'first', 'computer,', 'it', 'was', 'a', 'compaq', 'presario', 'cq57,', 'pretty', 'old', 'stuff,', 'but', 'it', 'was', 'the', 'beginning', 'for', 'me,', 'i', 'spent', 'a', 'lot', 'of', 'time', 'tinkering', 'with', 'it,', 'installing', 'games', 'and', 'deleting', 'them.eventually,', 'i', 'started', 'trying', 'to', 'edit', 'them,', 'i', 'failed', 'miserably,', 'but', 'i', 'learned', 'a', 'little', 'about', 'what', 'programs', 'were,', 'when', 'got', 'into', 'secondary', 'school', 'i', 'met', 'a', 'guy', 'called', 'izuchukuw,', 'who', 'game', 'me', 'some', 'ideas', 'about', 'programming,', 'i', 'could', 'remember', 'this', 'well', 'because', 'he', 'open', 'youtube', 'one', 'day', 'and', 'told', 'he', 'hacked', 'the', 'internet', 'to', 'view', 'the', 'videos', 'and', 'i', 'freaking', 'believed', 'him', ',', 'since', 'then', "it's", 'been', 'me', 'and', 'computers', 'and', 'programming', 'just', 'felt', 'right.before', 'i', 'got', 'into', 'programming', 'actively', 'was', 'about', 'a', 'year', 'after', 'secondary', 'school', 'and', 'i', 'wanted', 'to', 'learn', 'how', 'the', 'world', 'works', 'and', 'an', 'objective', 'look', 'at', 'myself', 'made', 'me', 'understand', 'that', 'i', 'wanted', 'to', 'do', 'this.', 'as', 'a', 'career,', 'so', 'i', 'worked', 'at', 'computer', 'village', 'for', 'a', 'year,', 'before', 'writing', 'jamb', 'for', 'computer', 'science', 'and', 'i', 'got', 'the', 'admission.', 'but', 'the', 'school', '(futo)', "didn't", 'teach', 'what', 'i', 'was', 'expecting,', 'so', 'i', 'started', 'actively', 'training', 'myself,', 'right', 'around', 'the', 'first', 'year.i', 'started', 'with', 'c++,', 'one', '1', 'hour', 'everyday', 'for', 'a', 'year,', 'and', 'then', 'java', 'before', 'getting', 'into', 'web', 'developmenti', "wouldn't", 'recommend', 'this', 'route', 'though,', 'all', 'it', 'did', 'for', 'me', 'was', 'to', 'give', 'me', 'some', 'grounded', 'understanding.if', 'there', 'was', 'anything', 'i', 'would', 'have', 'done', 'differently,-', 'i', 'would', 'have', 'focused', 'on', 'learning', 'more', 'about', 'what', 'the', 'languages', 'themselves', 'could', 'be', 'used', 'for-', 'focused', 'more', 'on', 'design', 'patterns-', 'mastering', 'singular', 'technologiesthe', 'key', 'is', 'to', 'know', 'exactly', 'what', 'you', 'want', 'from', 'your', 'career', 'as', 'a', 'developer', 'and', 'what', 'it', 'would', 'mean', 'for', 'you.', 'for', 'exa ...

# %%
clean_token =tokens[:]
#define irrelevant words that include stop words , punctuations and numbers
stopword = set(stopwords.words('english') + list(punctuation))
for token in tokens:
    if token in stopword:
        clean_token.remove(token)

print(clean_token)
# Out:
# ['guest', 'important', 'information', 'powered', 'lucidare', 'sure', 'want', 'unfollow', 'hng', 'internship', 'miss', 'interesting', 'post?', 'click', 'button', 'unfollowdo', 'would', 'love', 'lucid', 'installed', 'domain?', 'click', 'button', 'follow', 'home', 'blog', 'q&a', 'chibuike', 'ositahey', 'guys,', 'nice', 'hereso', 'name', 'chibuike', 'emmanuel', 'osita,', 'community', 'generally,', "i'm", 'commonly', 'known', 'mozart,', "i'm", 'software', 'engineer', 'proud', 'aluminai', 'internship.', "i'm", 'really', 'happy', 'space', 'again.in', 'order', 'ensure', 'organized,', "i'll", 'talk', 'following', 'questions.-', 'became', 'developer-', 'learned', 'internship-', 'becoming', 'product', 'creator-', 'created', 'legohackers-', 'things', 'focus', 'improve', 'skills.why', 'became', "developerlet's", 'start', 'beginning', 'briefly,', 'wanted', 'aeronautics', 'engineer,', 'since', 'little,', 'aside', 'becoming', 'spiderman,', 'thing', 'found', 'thinking', 'constantly.', 'dad', 'got', 'brother', 'first', 'computer,', 'compaq', 'presario', 'cq57,', 'pretty', 'old', 'stuff,', 'beginning', 'me,', 'spent', 'lot', 'time', 'tinkering', 'it,', 'installing', 'games', 'deleting', 'them.eventually,', 'started', 'trying', 'edit', 'them,', 'failed', 'miserably,', 'learned', 'little', 'programs', 'were,', 'got', 'secondary', 'school', 'met', 'guy', 'called', 'izuchukuw,', 'game', 'ideas', 'programming,', 'could', 'remember', 'well', 'open', 'youtube', 'one', 'day', 'told', 'hacked', 'internet', 'view', 'videos', 'freaking', 'believed', 'since', 'computers', 'programming', 'felt', 'right.before', 'got', 'programming', 'actively', 'year', 'secondary', 'school', 'wanted', 'learn', 'world', 'works', 'objective', 'look', 'made', 'understand', 'wanted', 'this.', 'career,', 'worked', 'computer', 'village', 'year,', 'writing', 'jamb', 'computer', 'science', 'got', 'admission.', 'school', '(futo)', 'teach', 'expecting,', 'started', 'actively', 'training', 'myself,', 'right', 'around', 'first', 'year.i', 'started', 'c++,', 'one', '1', 'hour', 'everyday', 'year,', 'java', 'getting', 'web', 'developmenti', 'recommend', 'route', 'though,', 'give', 'grounded', 'understanding.if', 'anything', 'would', 'done', 'differently,-', 'would', 'focused', 'learning', 'languages', 'could', 'used', 'for-', 'focused', 'design', 'patterns-', 'mastering', 'singular', 'technologiesthe', 'key', 'know', 'exactly', 'want', 'career', 'developer', 'would', 'mean', 'you.', 'example,', 'enthusiasm,', 'learned', 'different', 'languages,', 'use', '(e.g', 'c++),', 'get', 'learn', 'design', 'patterns', 'later,', 'always', 'felt', 'started', 'somewhere', 'around', 'order', 'understand', 'bigger', 'picture.singular', 'technologies', 'things', 'related', 'singular', 'language', 'frameworks,', 'everything', 'concerns', 'language', 'working', 'on,', 'e.g', 'php', 'laravel,', 'know', 'php,', 'master', 'master', 'laravel', 'everything', 'concerning', 'language', 'framework', 'circle', 'control', 'understanding.at', 'end', 'though,', "i'm", 'happy', 'path,', 'follow', 'key', 'points,', 'likely', 'get', 'ideas', 'faster.before', 'end', 'sections', '(why', 'became', 'developer)', 'though,', 'following', 'mind.-', 'follow', 'buzzwords,', 'end,', 'technologies', 'same.-', 'simplest', 'solution', 'language', 'understand', 'use', 'likely', 'best', "(occam's", 'razor)-', 'focus', 'essentials,', '(is', 'understandable,', 'work,', 'soon', 'get', 'running)the', 'essentials', 'may', 'different', 'you,', 'always', 'keep', 'mind.what', 'learnt', 'internshipthe', 'internship', 'started', 'finished', 'second', 'year', 'school,', 'third', 'semester', 'beginning,', 'thousand,', 'really', 'loved', 'it15:32before', 'known', 'developers,', 'internship,', 'mad', 'new', 'opportunity', 'meet', 'really', 'ingenious', 'people.', 'collaborated,', 'fought', 'argued', 'learnt', 'together', 'made', 'understand', 'following', 'points.-', 'team', 'would', 'work', 'members', 'working', 'leader', 'team', 'understand', 'prob ...

# %%
freq = nltk.FreqDist(clean_token)
top_words=[]
top_words=freq.most_common(100)
print(top_words)
# Out:
# [('would', 20), ('know', 17), ('one', 15), ('learn', 15), ('understand', 14), ('product', 13), ('get', 13), ("i'm", 11), ('use', 11), ('language', 11), ('really', 10), ('need', 10), ('important', 9), ('start', 9), ('want', 8), ('time', 8), ('work', 8), ('build', 8), ('make', 8), ('thing', 7), ('thinking', 7), ('first', 7), ('master', 7), ('good', 7), ('building', 7), ('things', 6), ('design', 6), ('different', 6), ('something', 6), ('focus', 5), ('started', 5), ('well', 5), ('used', 5), ('may', 5), ("that's", 5), ('become', 5), ('time,', 5), ('well,', 5), ('much', 5), ('go', 5), ('becoming', 4), ('created', 4), ('improve', 4), ('wanted', 4), ('got', 4), ('trying', 4), ('focused', 4), ('learning', 4), ('everything', 4), ('working', 4), ('likely', 4), ('new', 4), ('team', 4), ('products,', 4), ('takes', 4), ('products', 4), ('find', 4), ('developers', 4), ('people', 4), ('enough', 4), ('take', 4), ('think', 4), ('buffers', 4), ('frontend', 4), ('project', 4), ('step', 4), ('follow', 3), ('software', 3), ('order', 3), ('talk', 3), ('following', 3), ('became', 3), ('learned', 3), ('me,', 3), ('school', 3), ('ideas', 3), ('could', 3), ('year', 3), ('look', 3), ('made', 3), ('year,', 3), ('around', 3), ('though,', 3), ('languages', 3), ('key', 3), ('developer', 3), ('on,', 3), ('e.g', 3), ('end', 3), ('keep', 3), ('thing,', 3), ('code', 3), ('following.-', 3), ('questions', 3), ('avoid', 3), ('going', 3), ('like', 3), ('legohackers', 3), ('platform', 3), ('problems', 3)]

# %%
sentences = sent_tokenize(text)
print(sentences)
# Out:
# [' guest\n          important information\n        powered by lucidare you sure you want to unfollow hng internship and miss out interesting post?', 'click the button below to unfollowdo you have or would love to have lucid installed on your domain?', "click the button below to follow me\n home  /\n             blog  / q&a with chibuike ositahey guys, it's nice to be hereso my name is chibuike emmanuel osita, but in the community and generally, i'm more commonly known as mozart, i'm a software engineer and a proud aluminai of this internship.", "so i'm really happy to be in this space again.in order to ensure this is organized, i'll talk about the following before the questions.- why i became a developer- what i learned from the internship- becoming a product creator- why i created legohackers- things to focus on to improve your skills.why i became a developerlet's start from the beginning very briefly, i wanted to be an aeronautics engineer, a since i was little, aside becoming spiderman, it's the only thing i found myself thinking about constantly.", "until my dad got i and my brother our first computer, it was a compaq presario cq57, pretty old stuff, but it was the beginning for me, i spent a lot of time tinkering with it, installing games and deleting them.eventually, i started trying to edit them, i failed miserably, but i learned a little about what programs were, when got into secondary school i met a guy called izuchukuw, who game me some ideas about programming, i could remember this well because he open youtube one day and told he hacked the internet to view the videos and i freaking believed him\xa0, since then it's been me and computers and programming just felt right.before i got into programming actively was about a year after secondary school and i wanted to learn how the world works and an objective look at myself made me understand that i wanted to do this.", 'as a career, so i worked at computer village for a year, before writing jamb for computer science and i got the admission.', "but the school (futo) didn't teach what i was expecting, so i started actively training myself, right around the first year.i started with c++, one 1 hour everyday for a year, and then java before getting into web developmenti wouldn't recommend this route though, all it did for me was to give me some grounded understanding.if there was anything i would have done differently,- i would have focused on learning more about what the languages themselves could be used for- focused more on design patterns- mastering singular technologiesthe key is to know exactly what you want from your career as a developer and what it would mean for you.", "for example, because of my enthusiasm, i learned different languages, some of which i didn't use at all (e.g c++), i did get to learn design patterns later, but i always felt i should have started somewhere around there in order to understand the bigger picture.singular technologies are all things related to a singular language and it's frameworks, it's everything that concerns the language you are working on, e.g php and laravel, if you know php, master it and master laravel , so everything concerning it as a language and its framework is in your circle of control and understanding.at the end though, i'm happy about my path, but if you follow the key points, you'll likely get to your ideas faster.before i end this sections (why i became a developer) though, just have the following in mind.- don't just follow buzzwords, at the end, all of these technologies are the same.- and the simplest solution or language to understand and use is most likely the best for you (occam's razor)- focus on the essentials, (is it understandable, does it work, how soon can i get up and running)the essentials may be different for you, but always keep them in mind.what i learnt from the internshipthe internship started when i just finished my second year in school, the third semester was just beginning, we were more tha ...

# %%
#Iterating through all the sentences from the web to create a ranking for each sentence

ranking = defaultdict(int)
for i, sent in enumerate(sentences):
    for word in word_tokenize(sent.lower()):
        if word in freq:
            ranking[i]+=freq[word]
    top_sentences = nlargest(10, ranking, ranking.get)
print(top_sentences)
# Out:
# [13, 8, 27, 7, 29, 36, 6, 15, 10, 24]

# %%
#printing one of the top 2 sentences
print(sentences[27])
# Out:
# that would allow me do both the frontend and the back end with ease (javascript ), i need to build a good frontend and i would need good templates for it ( www.creative-tim.com , the dude creates reusable templates in their hundreds )q: does it mean i can not become full-stack,in terms of mastering one thing?a: it's one at a time, you can get there, but make it easy for yourself, if you know javascript for frontend, you can easily learn node, and if you know node, you'll likely understand rest, and the design patterns that come along, e.g mvc, class first systems etc, if you know design patterns, you'll likely be able to understand what php, c# or golang is used for, and can go ahead to learn any of them if you what to.it's a step by step process, and if you want to get there you can, more easily if you master one at a timeq: also if you are in a collaborative project and the language of the group is quite different from the one you know what do you do?

# %%
#Sorting all sentences
sorted_sentences = [sentences[j] for j in sorted(top_sentences)]
print(sorted_sentences)
# Out:
# ["but the school (futo) didn't teach what i was expecting, so i started actively training myself, right around the first year.i started with c++, one 1 hour everyday for a year, and then java before getting into web developmenti wouldn't recommend this route though, all it did for me was to give me some grounded understanding.if there was anything i would have done differently,- i would have focused on learning more about what the languages themselves could be used for- focused more on design patterns- mastering singular technologiesthe key is to know exactly what you want from your career as a developer and what it would mean for you.", "for example, because of my enthusiasm, i learned different languages, some of which i didn't use at all (e.g c++), i did get to learn design patterns later, but i always felt i should have started somewhere around there in order to understand the bigger picture.singular technologies are all things related to a singular language and it's frameworks, it's everything that concerns the language you are working on, e.g php and laravel, if you know php, master it and master laravel , so everything concerning it as a language and its framework is in your circle of control and understanding.at the end though, i'm happy about my path, but if you follow the key points, you'll likely get to your ideas faster.before i end this sections (why i became a developer) though, just have the following in mind.- don't just follow buzzwords, at the end, all of these technologies are the same.- and the simplest solution or language to understand and use is most likely the best for you (occam's razor)- focus on the essentials, (is it understandable, does it work, how soon can i get up and running)the essentials may be different for you, but always keep them in mind.what i learnt from the internshipthe internship started when i just finished my second year in school, the third semester was just beginning, we were more than a thousand, and i really loved it15:32before then i had known only a few other developers, but with the internship, i mad a new opportunity to meet some really ingenious people.", "we collaborated, fought argued and learnt together and it made me understand the following points.-\xa0a team would only work if it's members are working\xa0-\xa0the leader of the team understand the problem, before the members can get to work-\xa0a team needs a leader-\xa0consequences are important to maintain order and structure\xa0-\xa0in the end, the team is the most important thing, not winning, after them winning is the most important thing-\xa0understand what is required to win, then do it +1becoming a product creatorwriting code is different from creating products, and that's why it may be difficult to understand what a product creator is.a product creator is simply a person who has understood that code is not all it takes to build a good product.coding is the easier thing to do, and having been developing for 4+ years, it's still hard to accept, but must be accepted.when you have an idea and you want to have it become a product, it's important to understand the following.-\xa0what problem am i trying to solve-\xa0who are the users (remember this is not the whole world, it's just a very few people)-\xa0why would they use it-\xa0what is the most important thing it is supposed to do\xa0- this is what you map (minimum awesome product) is, only that most important thingthe questions you should avoid early on are questions like15:46- what language should i use?- is angular better than react for this?- etc\xa0i hope you know what i mean.most products today are not going to be mvps anymore if you are going to build something make it awesome, it's the very first version.", "this is quite simple, i created legohackers with the intention to help other developers graduate from just being coders, into product creators, it's being a bit rough, in its growth because i'm learning as i improve it and i'm getting to know more abo ...

# %%
with open('sorted_sentences.txt', 'w') as f:
    for i in sorted_sentences:
        f.write(i+"\n")
